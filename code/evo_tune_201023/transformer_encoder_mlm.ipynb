# %% [markdown]
# # Documentation
# > The following code adopted from transformer_encoder_ver2 (a smaller embedding and FDN with the hope of getting less concentrated features). It further exapanded by applying a masked language model.
#
# > In the previous model, a mask is applied so that at each word, it sees only the word prior to it. (When predicting #2 word, it sees only #1 word, and all rest are masked to -INF), so that the model follows an auto-regressive manner
#
# > In the MLM setting, certain proportion of the sentense is randomly masked (15% in BERT), and they are masked throughout the training process. The loss is only on those positions's correctness. In the TransformerEncoderLayer, the mask pass in should be changed and should mask the position of mask to -INF while keeping all the rest to 0.

# %%
import math
import torch.nn as nn
import argparse
import random
import warnings
import numpy as np
import torch
import torch.nn.functional as F
from torch import optim
import torch.backends.cudnn as cudnn
from torch.utils.data import DataLoader
from torch.utils.data import Dataset
from torch.autograd import Variable
import itertools
import pandas as pd
from torch.nn import TransformerEncoder, TransformerEncoderLayer
import math

seed = 7
torch.manual_seed(seed)
np.random.seed(seed)


pfamA_motors = pd.read_csv("../../data/pfamA_motors.csv")
df_dev = pd.read_csv("../../data/df_dev.csv")
motor_toolkit = pd.read_csv("../../data/motor_tookits.csv")

pfamA_motors_balanced = pfamA_motors.groupby('clan').apply(lambda _df: _df.sample(4500,random_state=1))
pfamA_motors_balanced = pfamA_motors_balanced.apply(lambda x: x.reset_index(drop = True))

pfamA_target_name = ["PF00349","PF00022","PF03727","PF06723",\
                       "PF14450","PF03953","PF12327","PF00091","PF10644",\
                      "PF13809","PF14881","PF00063","PF00225","PF03028"]

pfamA_target = pfamA_motors.loc[pfamA_motors["pfamA_acc"].isin(pfamA_target_name),:]


# shuffle pfamA_target and pfamA_motors_balanced
pfamA_target = pfamA_target.sample(frac = 1)
pfamA_target_ind = pfamA_target.iloc[:,0]
print(pfamA_target_ind[0:5])
print(pfamA_motors_balanced.shape)

pfamA_motors_balanced = pfamA_motors_balanced.sample(frac = 1) 
pfamA_motors_balanced_ind = pfamA_motors_balanced.iloc[:,0]
print(pfamA_motors_balanced_ind[0:5])
print(pfamA_target.shape)
# Out:
# 179519      179519
# 1414859    1414859
# 12920        12920
# 1415258    1415258
# 13385        13385
# Name: Unnamed: 0, dtype: int64
# (18000, 6)
# 13493    180756
# 1539     166414
# 2688     131988
# 1691      37094
# 188      130155
# Name: Unnamed: 0, dtype: int64
# (59149, 6)

# %%
aminoacid_list = [
    'A', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'K', 'L',
    'M', 'N', 'P', 'Q', 'R', 'S', 'T', 'V', 'W', 'Y'
]
clan_list = ["actin_like","tubulin_c","tubulin_binding","p_loop_gtpase"]
        
aa_to_ix = dict(zip(aminoacid_list, np.arange(1, 21)))
clan_to_ix = dict(zip(clan_list, np.arange(0, 4)))

def word_to_index(seq,to_ix):
    "Returns a list of indices (integers) from a list of words."
    return [to_ix.get(word, 0) for word in seq]

ix_to_aa = dict(zip(np.arange(1, 21), aminoacid_list))
ix_to_clan = dict(zip(np.arange(0, 4), clan_list))

def index_to_word(ixs,ix_to): 
    "Returns a list of words, given a list of their corresponding indices."
    return [ix_to.get(ix, 'X') for ix in ixs]

# %%
def prepare_sequence(seq):
    idxs = word_to_index(seq[:],aa_to_ix)
    return torch.tensor(idxs, dtype=torch.long)

# def prepare_labels(seq):
#     idxs = word_to_index(seq[1:],aa_to_ix)
#     return torch.tensor(idxs, dtype=torch.long)

def prepare_eval(seq):
    idxs = word_to_index(seq[:],aa_to_ix)
    return torch.tensor(idxs, dtype=torch.long)

prepare_sequence('YCHXXXXX')
# Out:
# tensor([20,  2,  7,  0,  0,  0,  0,  0])

# %%
# set device
device  = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
class PositionalEncoding(nn.Module):
    """
    PositionalEncoding module injects some information about the relative or absolute position of
    the tokens in the sequence. The positional encodings have the same dimension as the embeddings 
    so that the two can be summed. Here, we use sine and cosine functions of different frequencies.
    """
    def __init__(self, d_model, dropout=0.1, max_len=5000):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=dropout)
        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0).transpose(0, 1)
        
#         pe[:, 0::2] = torch.sin(position * div_term)
#         pe[:, 1::2] = torch.cos(position * div_term)
#         pe = pe.unsqueeze(0)
        
        self.register_buffer('pe', pe)

    def forward(self, x):
#         x = x + self.pe[:x.size(0), :]
#         print("x.size() : ", x.size())
#         print("self.pe.size() :", self.pe[:x.size(0),:,:].size())
        x = torch.add(x ,Variable(self.pe[:x.size(0),:,:], requires_grad=False))
        return self.dropout(x)

    
    
class TransformerModel(nn.Module):

    def __init__(self, ntoken, ninp, nhead, nhid, nlayers, dropout=0.5):
        super(TransformerModel, self).__init__()
        
        self.model_type = 'Transformer'
        self.src_mask = None
        self.pos_encoder = PositionalEncoding(ninp)
        encoder_layers = TransformerEncoderLayer(ninp, nhead, nhid, dropout,activation='gelu')
        self.transformer_encoder = TransformerEncoder(encoder_layers, nlayers)
        self.encoder = nn.Embedding(ntoken, ninp)
        self.ninp = ninp
        self.decoder = nn.Linear(ninp, ntoken)

        self.init_weights()

    def _generate_square_subsequent_mask(self, sz):
        mask = (torch.triu(torch.ones(sz, sz)) == 1).transpose(0, 1)
        mask = mask.float().masked_fill(mask == 0, float('-inf')).masked_fill(mask == 1, float(0.0))
        return mask
    
#     def _generate_square_mlm_mask(self, sz):
#         # 0's are the masked position
#         zeros_num = int(sz * mask_frac)
#         ones_num = sz - zeros_num
#         lm_mask = torch.cat([torch.zeros(zeros_num), torch.ones(ones_num)])
#         lm_mask = lm_mask[torch.randperm(sz)]
#         masked_ind = lm_mask.eq(0)
#         lm_mask = lm_mask.repeat(sz, 1)
#         mask = lm_mask.float().masked_fill(lm_mask == 0, float('-inf')).masked_fill(lm_mask == 1, float(0.0))
#         mask = mask.to(device)
#         return mask,masked_ind
        
        
    def init_weights(self):
        initrange = 0.1
        self.encoder.weight.data.uniform_(-initrange, initrange)
        self.decoder.bias.data.zero_()
        self.decoder.weight.data.uniform_(-initrange, initrange)

    def forward(self, src,lm_mask):
#         if model.training:
#             device = src.device
#             mask = self._generate_square_mlm_mask(src.size(0))
            
#         print("src.device: ", src.device)
        src = self.encoder(src) * math.sqrt(self.ninp)
#         print("self.encoder(src) size: ", src.size())
        src = self.pos_encoder(src)
#         print("elf.pos_encoder(src) size: ", src.size())
        output = self.transformer_encoder(src, lm_mask)
#         print("output size: ", output.size())
        output = self.decoder(output)
        return output

# %%
ntokens = len(aminoacid_list) + 1 # the size of vocabulary
emsize = 12 # embedding dimension
nhid = 100 # the dimension of the feedforward network model in nn.TransformerEncoder
nlayers = 6 # the number of nn.TransformerEncoderLayer in nn.TransformerEncoder
nhead = 12 # the number of heads in the multiheadattention models
dropout = 0.1 # the dropout value
model = TransformerModel(ntokens, emsize, nhead, nhid, nlayers, dropout)

# %%
criterion = nn.CrossEntropyLoss()
lr = 3.0 # learning rate
optimizer = torch.optim.SGD(model.parameters(), lr=lr)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, 1.0, gamma=0.95)

# %%
model.to(device)
model.train() # Turn on the train mode
# Out:
# TransformerModel(
#   (pos_encoder): PositionalEncoding(
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (transformer_encoder): TransformerEncoder(
#     (layers): ModuleList(
#       (0): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): Linear(in_features=12, out_features=12, bias=True)
#         )
#         (linear1): Linear(in_features=12, out_features=100, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=100, out_features=12, bias=True)
#         (norm1): LayerNorm((12,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((12,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#       )
#       (1): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): Linear(in_features=12, out_features=12, bias=True)
#         )
#         (linear1): Linear(in_features=12, out_features=100, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=100, out_features=12, bias=True)
#         (norm1): LayerNorm((12,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((12,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#       )
#       (2): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): Linear(in_features=12, out_features=12, bias=True)
#         )
#         (linear1): Linear(in_features=12, out_features=100, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=100, out_features=12, bias=True)
#         (norm1): LayerNorm((12,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((12,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#       )
#       (3): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): Linear(in_features=12, out_features=12, bias=True)
#         )
#         (linear1): Linear(in_features=12, out_features=100, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=100, out_features=12, bias=True)
#         (norm1): LayerNorm((12,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((12,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#       )
#       (4): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): Linear(in_features=12, out_features=12, bias=True)
#         )
#         (linear1): Linear(in_features=12, out_features=100, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=100, out_features=12, bias=True)
#         (norm1): LayerNorm((12,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((12,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#       )
#       (5): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): Linear(in_features=12, out_features=12, bias=True)
#         )
#         (linear1): Linear(in_features=12, out_features=100, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=100, out_features=12, bias=True)
#         (norm1): LayerNorm((12,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((12,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#       )
#     )
#   )
#   (encoder): Embedding(21, 12)
#   (decoder): Linear(in_features=12, out_features=21, bias=True)
# )

# %%
import time

# %%
start_time = time.time()
print_every = 1000
# loss_vector = []
mask_frac = 0.15

for epoch in np.arange(0, df_dev.shape[0]): 
    seq = df_dev.iloc[epoch, 6]
    sz = len(seq)
    zeros_num = int(sz * mask_frac)
    ones_num = sz - zeros_num
    lm_mask = torch.cat([torch.zeros(zeros_num), torch.ones(ones_num)])
    lm_mask = lm_mask[torch.randperm(sz)]
    mask_ind = lm_mask.eq(0)
    lm_mask = lm_mask.repeat(sz, 1)
    lm_mask = lm_mask.float().masked_fill(lm_mask == 0, float('-inf')).masked_fill(lm_mask == 1, float(0.0))
    lm_mask = lm_mask.to(device)

    sentence_in = prepare_sequence(seq)
#     sentence_in = sentence_in.to(device = device)
    sentence_in = sentence_in.unsqueeze(1).to(device = device)

    optimizer.zero_grad()
    output = model(sentence_in,lm_mask)
#     print(mask_ind)
    targets = sentence_in[mask_ind]
#     targets = targets.to(device = device)
    
    print(targets.squeeze(1).size())
    print(output[mask_ind].squeeze(1).size())

    loss = criterion(output[mask_ind].squeeze(1), targets.squeeze(1))
    loss.backward()
    torch.nn.utils.clip_grad_norm_(model.parameters(), 0.5)
    optimizer.step()
    if epoch % print_every == 0:
        print(f"At Epoch: %.1f"% epoch)
        print(f"Loss %.4f"% loss)
        elapsed = time.time() - start_time
        print(f"time elapsed %.4f"% elapsed)
#         torch.save(model.state_dict(), "../../data/transformer_encoder_201025.pt")
#     loss_vector.append(loss)
    break
# Out:
# torch.Size([17])
# torch.Size([17, 21])
# At Epoch: 0.0
# Loss 3.0147
# time elapsed 0.0404

# %%
start_time = time.time()
print_every = 1000
# loss_vector = []
mask_frac = 0.15

for epoch in np.arange(409000, df_dev.shape[0]): 
    seq = df_dev.iloc[epoch, 6]
#     print(seq)
    
    sz = len(seq)
#     print(sz)
    zeros_num = int(sz * mask_frac)
    if zeros_num < 1:
        continue
    ones_num = sz - zeros_num
    lm_mask = torch.cat([torch.zeros(zeros_num), torch.ones(ones_num)])
    lm_mask = lm_mask[torch.randperm(sz)]
    mask_ind = lm_mask.eq(0)
    lm_mask = lm_mask.repeat(sz, 1)
    lm_mask = lm_mask.float().masked_fill(lm_mask == 0, float('-inf')).masked_fill(lm_mask == 1, float(0.0))
    lm_mask = lm_mask.to(device)

    sentence_in = prepare_sequence(seq)
#     sentence_in = sentence_in.to(device = device)
    sentence_in = sentence_in.unsqueeze(1).to(device = device)

    optimizer.zero_grad()
    output = model(sentence_in,lm_mask)
#     print(mask_ind)
    targets = sentence_in[mask_ind]
#     targets = targets.to(device = device)
    
#     print(targets.squeeze(1).size())
#     print(output[mask_ind].squeeze(1).size())

    loss = criterion(output[mask_ind].squeeze(1), targets.squeeze(1))
    loss.backward()
    torch.nn.utils.clip_grad_norm_(model.parameters(), 0.5)
    optimizer.step()
    if epoch % print_every == 0:
        print(f"At Epoch: %.1f"% epoch)
        print(f"Loss %.4f"% loss)
        elapsed = time.time() - start_time
        print(f"time elapsed %.4f"% elapsed)
#         torch.save(model.state_dict(), "../../data/transformer_encoder_201025.pt")
#     loss_vector.append(loss)
#     break
# Out:
# At Epoch: 409000.0
# Loss 2.9233
# time elapsed 0.0420
# At Epoch: 410000.0
# Loss 3.0972
# time elapsed 21.4877
# At Epoch: 411000.0
# Loss 2.8950
# time elapsed 42.8958
# At Epoch: 412000.0
# Loss 2.8483
# time elapsed 63.4584
# At Epoch: 413000.0
# Loss 2.9233
# time elapsed 84.2736
# At Epoch: 414000.0
# Loss 3.0290
# time elapsed 104.3078
# At Epoch: 415000.0
# Loss 2.8642
# time elapsed 124.5025
# At Epoch: 416000.0
# Loss 2.9257
# time elapsed 144.6149
# At Epoch: 417000.0
# Loss 3.1042
# time elapsed 164.7017
# At Epoch: 418000.0
# Loss 2.9663
# time elapsed 184.9746
# At Epoch: 419000.0
# Loss 2.8315
# time elapsed 204.7974
# At Epoch: 420000.0
# Loss 3.0034
# time elapsed 224.5893
# At Epoch: 421000.0
# Loss 2.9070
# time elapsed 244.4433
# At Epoch: 422000.0
# Loss 2.8272
# time elapsed 264.1716
# At Epoch: 423000.0
# Loss 2.9028
# time elapsed 284.2062
# At Epoch: 424000.0
# Loss 3.1271
# time elapsed 304.0006
# At Epoch: 425000.0
# Loss 2.8654
# time elapsed 323.6824
# At Epoch: 426000.0
# Loss 2.9949
# time elapsed 343.4006
# At Epoch: 427000.0
# Loss 2.9270
# time elapsed 363.1939
# At Epoch: 428000.0
# Loss 2.9083
# time elapsed 382.9424
# At Epoch: 429000.0
# Loss 3.7211
# time elapsed 402.8581
# At Epoch: 430000.0
# Loss 2.9518
# time elapsed 422.7349
# At Epoch: 431000.0
# Loss 3.0226
# time elapsed 442.6508
# At Epoch: 432000.0
# Loss 2.8764
# time elapsed 462.6409
# At Epoch: 433000.0
# Loss 2.6425
# time elapsed 483.5433
# At Epoch: 434000.0
# Loss 3.2313
# time elapsed 503.3454
# At Epoch: 435000.0
# Loss 2.9329
# time elapsed 523.2113
# At Epoch: 436000.0
# Loss 2.9502
# time elapsed 543.0267
# At Epoch: 437000.0
# Loss 2.9752
# time elapsed 562.8010
# At Epoch: 438000.0
# Loss 2.7048
# time elapsed 582.7515
# At Epoch: 439000.0
# Loss 2.9490
# time elapsed 602.5728
# At Epoch: 440000.0
# Loss 2.8107
# time elapsed 622.4333
# At Epoch: 441000.0
# Loss 3.0270
# time elapsed 641.8577
# At Epoch: 442000.0
# Loss 2.8204
# time elapsed 661.1282
# At Epoch: 443000.0
# Loss 2.8567
# time elapsed 680.6967
# At Epoch: 444000.0
# Loss 2.9349
# time elapsed 700.7115
# At Epoch: 445000.0
# Loss 3.1749
# time elapsed 721.1328
# At Epoch: 446000.0
# Loss 2.6513
# time elapsed 740.6906
# At Epoch: 447000.0
# Loss 2.9637
# time elapsed 760.6797
# At Epoch: 448000.0
# Loss 3.1768
# time elapsed 779.8835
# At Epoch: 449000.0
# Loss 3.0193
# time elapsed 799.5131
# At Epoch: 450000.0
# Loss 3.0995
# time elapsed 818.6746
# At Epoch: 451000.0
# Loss 3.3040
# time elapsed 837.9608
# At Epoch: 452000.0
# Loss 2.7146
# time elapsed 857.1521
# At Epoch: 453000.0
# Loss 2.7993
# time elapsed 876.4322
# At Epoch: 454000.0
# Loss 3.4924
# time elapsed 895.7157
# At Epoch: 455000.0
# Loss 3.0467
# time elapsed 915.4924
# At Epoch: 456000.0
# Loss 3.0056
# time elapsed 935.9392
# At Epoch: 457000.0
# Loss 2.8967
# time elapsed 955.4695
# At Epoch: 458000.0
# Loss 3.1643
# time elapsed 975.2128
# At Epoch: 459000.0
# Loss 2.9896
# time elapsed 994.5847
# At Epoch: 460000.0
# Loss 2.7782
# time elapsed 1013.8629
# At Epoch: 461000.0
# Loss 2.7635
# time elapsed 1033.0965
# At Epoch: 462000.0
# Loss 2.9014
# time elapsed 1052.4436
# At Epoch: 463000.0
# Loss 2.9525
# time elapsed 1071.7414
# At Epoch: 464000.0
# Loss 3.0743
# time elapsed 1091.0734
# At Epoch: 465000.0
# Loss 2.7065
# time elapsed 1110.4750
# At Epoch: 466000.0
# Loss 2.6266
# time elapsed 1129.6382
# At Epoch: 467000.0
# Loss 2.9452
# time elapsed 1148.8665
# At Epoch: 468000.0
# Loss 3.2057
# time elapsed 1168.1957
# At Epoch: 469000.0
# Loss 2.7372
# time elapsed 1187.4897
# At Epoch: 470000.0
# Loss 2.9279
# time elapsed 1206.7600
# At Epoch: 471000.0
# Loss 2.8159
# time elapsed 1226.0983
# At Epoch: 472000.0
# Loss 3.0234
# time elapsed 1245.5037
# At Epoch: 473000.0
# Loss 3.0674
# time elapsed 1264.8562
# At Epoch: 474000.0
# Loss 3.0403
# time elapsed 1284.1643
# At Epoch: 475000.0
# Loss 2.8047
# time elapsed 1303.2304
# At Epoch: 476000.0
# Loss 3.0746
# time elapsed 1322.5789
# At Epoch: 477000.0
# Loss 3.2926
# time elapsed 1341.6645
# At Epoch: 478000.0
# Loss 3.4231
# time elapsed 1360.8691
# At Epoch: 479000.0
# Loss 2.8269
# time elapsed 1379.9076
# At Epoch: 480000.0
# Loss 2.8867
# time elapsed 1398.9803
# At Epoch: 481000.0
# Loss 3.1274
# time elapsed 1418.0447
# At Epoch: 482000.0
# Loss 3.0835
# time elapsed 1437.1279
# At Epoch: 483000.0
# Loss 3.0767
# time elapsed 1456.5474
# At Epoch: 484000.0
# Loss 2.6140
# time elapsed 1475.6300
# At Epoch: 485000.0
# Loss 3.0794
# time elapsed 1495.0397
# At Epoch: 486000.0
# Loss 3.2501
# time elapsed 1514.2221
# At Epoch: 487000.0
# Loss 3.3393
# time elapsed 1533.9170
# At Epoch: 488000.0
# Loss 2.8604
# time elapsed 1553.2772
# At Epoch: 489000.0
# Loss 3.2074
# time elapsed 1572.7054
# At Epoch: 490000.0
# Loss 3.2447
# time elapsed 1592.2445
# At Epoch: 491000.0
# Loss 2.8234
# time elapsed 1611.5823
# At Epoch: 492000.0
# Loss 3.1564
# time elapsed 1630.9233
# At Epoch: 493000.0
# Loss 2.5907
# time elapsed 1650.2881
# At Epoch: 494000.0
# Loss 3.2599
# time elapsed 1670.0121
# At Epoch: 495000.0
# Loss 2.8836
# time elapsed 1690.2441
# At Epoch: 496000.0
# Loss 3.5397
# time elapsed 1710.0505
# At Epoch: 497000.0
# Loss 3.4544
# time elapsed 1729.2236
# At Epoch: 498000.0
# Loss 2.8999
# time elapsed 1748.6299
# At Epoch: 499000.0
# Loss 3.0077
# time elapsed 1767.7004
# At Epoch: 500000.0
# Loss 3.0420
# time elapsed 1786.7408
# At Epoch: 501000.0
# Loss 3.0391
# time elapsed 1806.0625
# At Epoch: 502000.0
# Loss 2.9458
# time elapsed 1826.1421
# At Epoch: 503000.0
# Loss 3.1278
# time elapsed 1846.1148
# At Epoch: 504000.0
# Loss 3.2726
# time elapsed 1865.8465
# At Epoch: 505000.0
# Loss 2.9372
# time elapsed 1885.8961
# At Epoch: 506000.0
# Loss 2.9985
# time elapsed 1905.4692
# At Epoch: 507000.0
# Loss 2.8549
# time elapsed 1924.8120
# At Epoch: 508000.0
# Loss 2.6682
# time elapsed 1944.3336
# At Epoch: 509000.0
# Loss 3.3950
# time elapsed 1963.7871
# At Epoch: 510000.0
# Loss 2.6757
# time elapsed 1983.2188
# At Epoch: 511000.0
# Loss 2.9156
# time elapsed 2002.5910
# At Epoch: 512000.0
# Loss 2.9533
# time elapsed 2022.0311
# At Epoch: 513000.0
# Loss 3.2365
# time elapsed 2041.2873
# At Epoch: 514000.0
# Loss 3.1684
# time elapsed 2060.7305
# At Epoch: 515000.0
# Loss 2.7938
# time elapsed 2080.0516
# At Epoch: 516000.0
# Loss 2.9526
# time elapsed 2100.1678
# At Epoch: 517000.0
# Loss 2.7706
# time elapsed 2119.6843
# At Epoch: 518000.0
# Loss 3.1504
# time elapsed 2139.0839
# At Epoch: 519000.0
# Loss 2.8143
# time elapsed 2158.2397
# At Epoch: 520000.0
# Loss 3.0489
# time elapsed 2177.8735
# At Epoch: 521000.0
# Loss 2.2433
# time elapsed 2197.6254
# At Epoch: 522000.0
# Loss 2.8072
# time elapsed 2217.6578
# At Epoch: 523000.0
# Loss 2.8619
# time elapsed 2236.8754
# At Epoch: 524000.0
# Loss 3.0334
# time elapsed 2256.0067
# At Epoch: 525000.0
# Loss 2.9076
# time elapsed 2275.1058
# At Epoch: 526000.0
# Loss 3.2644
# time elapsed 2294.2020
# At Epoch: 527000.0
# Loss 3.0111
# time elapsed 2313.5016
# At Epoch: 528000.0
# Loss 2.9798
# time elapsed 2332.6703
# At Epoch: 529000.0
# Loss 2.8371
# time elapsed 2351.8955
# At Epoch: 530000.0
# Loss 3.0140
# time elapsed 2371.3484
# At Epoch: 531000.0
# Loss 3.1731
# time elapsed 2390.4628
# At Epoch: 532000.0
# Loss 2.8479
# time elapsed 2410.0909
# At Epoch: 533000.0
# Loss 3.2605
# time elapsed 2429.7361
# At Epoch: 534000.0
# Loss 3.0291
# time elapsed 2449.2223
# At Epoch: 535000.0
# Loss 2.8603
# time elapsed 2468.5616
# At Epoch: 536000.0
# Loss 2.7578
# time elapsed 2488.2935
# At Epoch: 537000.0
# Loss 3.0380
# time elapsed 2507.6256
# At Epoch: 538000.0
# Loss 3.4394
# time elapsed 2527.0208
# At Epoch: 539000.0
# Loss 3.2263
# time elapsed 2546.5197
# At Epoch: 540000.0
# Loss 3.1223
# time elapsed 2566.0525
# At Epoch: 541000.0
# Loss 2.9670
# time elapsed 2585.3719
# At Epoch: 542000.0
# Loss 2.6937
# time elapsed 2604.7172
# At Epoch: 543000.0
# Loss 2.8093
# time elapsed 2624.0901
# At Epoch: 544000.0
# Loss 3.0516
# time elapsed 2643.4930
# At Epoch: 545000.0
# Loss 2.8304
# time elapsed 2662.9016
# At Epoch: 546000.0
# Loss 3.0835
# time elapsed 2682.2679
# At Epoch: 547000.0
# Loss 3.1134
# time elapsed 2702.0277
# At Epoch: 548000.0
# Loss 3.0083
# time elapsed 2722.1476
# At Epoch: 549000.0
# Loss 2.8966
# time elapsed 2742.2924
# At Epoch: 550000.0
# Loss 2.7851
# time elapsed 2763.3859
# At Epoch: 551000.0
# Loss 3.0516
# time elapsed 2783.1053
# At Epoch: 552000.0
# Loss 3.0992
# time elapsed 2802.6418
# At Epoch: 553000.0
# Loss 2.7859
# time elapsed 2822.0847
# At Epoch: 554000.0
# Loss 3.3398
# time elapsed 2841.2072
# At Epoch: 555000.0
# Loss 3.1396
# time elapsed 2860.7674
# At Epoch: 556000.0
# Loss 3.4039
# time elapsed 2880.8891
# At Epoch: 557000.0
# Loss 3.2512
# time elapsed 2900.3084
# At Epoch: 558000.0
# Loss 3.0195
# time elapsed 2919.7433
# At Epoch: 559000.0
# Loss 2.9436
# time elapsed 2939.3025
# At Epoch: 560000.0
# Loss 2.9943
# time elapsed 2958.6766
# At Epoch: 561000.0
# Loss 3.0068
# time elapsed 2978.0795
# At Epoch: 562000.0
# Loss 2.8067
# time elapsed 2997.5154
# At Epoch: 563000.0
# Loss 2.7862
# time elapsed 3016.9134
# At Epoch: 564000.0
# Loss 3.0033
# time elapsed 3036.4787
# At Epoch: 565000.0
# Loss 3.0746
# time elapsed 3055.8076
# At Epoch: 566000.0
# Loss 3.1346
# time elapsed 3075.2744
# At Epoch: 567000.0
# Loss 2.8001
# time elapsed 3094.5744
# At Epoch: 568000.0
# Loss 2.9719
# time elapsed 3113.8396
# At Epoch: 569000.0
# Loss 3.0518
# time elapsed 3133.1251
# At Epoch: 570000.0
# Loss 2.8023
# time elapsed 3153.2113
# At Epoch: 571000.0
# Loss 3.1707
# time elapsed 3172.6268
# At Epoch: 572000.0
# Loss 3.0161
# time elapsed 3192.5412
# At Epoch: 573000.0
# Loss 3.0183
# time elapsed 3211.8664
# At Epoch: 574000.0
# Loss 2.7574
# time elapsed 3231.1118
# At Epoch: 575000.0
# Loss 2.9552
# time elapsed 3251.5716
# At Epoch: 576000.0
# Loss 2.9036
# time elapsed 3271.1131
# At Epoch: 577000.0
# Loss 3.0611
# time elapsed 3290.7239
# At Epoch: 578000.0
# Loss 3.0125
# time elapsed 3310.1727
# At Epoch: 579000.0
# Loss 2.8550
# time elapsed 3329.6687
# At Epoch: 580000.0
# Loss 2.8272
# time elapsed 3349.0268
# At Epoch: 581000.0
# Loss 2.8141
# time elapsed 3368.7124
# At Epoch: 582000.0
# Loss 3.5649
# time elapsed 3388.3271
# At Epoch: 583000.0
# Loss 2.9254
# time elapsed 3407.7045
# At Epoch: 584000.0
# Loss 2.9468
# time elapsed 3427.2484
# At Epoch: 585000.0
# Loss 2.9169
# time elapsed 3446.6493
# At Epoch: 586000.0
# Loss 2.8889
# time elapsed 3466.5650
# At Epoch: 587000.0
# Loss 2.8729
# time elapsed 3486.2381
# At Epoch: 588000.0
# Loss 3.3350
# time elapsed 3505.7630
# At Epoch: 589000.0
# Loss 3.1487
# time elapsed 3525.3337
# At Epoch: 590000.0
# Loss 2.8830
# time elapsed 3544.8174
# At Epoch: 591000.0
# Loss 2.6476
# time elapsed 3564.6266
# At Epoch: 592000.0
# Loss 3.3920
# time elapsed 3584.0371
# At Epoch: 593000.0
# Loss 3.0279
# time elapsed 3603.1513
# At Epoch: 594000.0
# Loss 2.4921
# time elapsed 3622.4846
# At Epoch: 595000.0
# Loss 3.0003
# time elapsed 3642.5242
# At Epoch: 596000.0
# Loss 3.0820
# time elapsed 3661.8682
# At Epoch: 597000.0
# Loss 2.8757
# time elapsed 3681.5261
# At Epoch: 598000.0
# Loss 2.9045
# time elapsed 3700.9311
# At Epoch: 599000.0
# Loss 2.8634
# time elapsed 3720.2275
# At Epoch: 600000.0
# Loss 2.9064
# time elapsed 3739.3020
# At Epoch: 601000.0
# Loss 3.1357
# time elapsed 3758.4234
# At Epoch: 602000.0
# Loss 2.8280
# time elapsed 3777.7289
# At Epoch: 603000.0
# Loss 2.9135
# time elapsed 3797.1258
# At Epoch: 604000.0
# Loss 2.9125
# time elapsed 3816.5851
# At Epoch: 605000.0
# Loss 3.5843
# time elapsed 3836.3591
# At Epoch: 606000.0
# Loss 3.0001
# time elapsed 3855.9306
# At Epoch: 607000.0
# Loss 2.7917
# time elapsed 3875.1885
# At Epoch: 608000.0
# Loss 3.0847
# time elapsed 3894.5935
# At Epoch: 609000.0
# Loss 2.8174
# time elapsed 3913.9536
# At Epoch: 610000.0
# Loss 2.6779
# time elapsed 3933.2052
# At Epoch: 611000.0
# Loss 3.2150
# time elapsed 3953.0342
# At Epoch: 612000.0
# Loss 2.7615
# time elapsed 3972.4384
# At Epoch: 613000.0
# Loss 3.1091
# time elapsed 3992.2467
# At Epoch: 614000.0
# Loss 3.1512
# time elapsed 4011.2552
# At Epoch: 615000.0
# Loss 2.9669
# time elapsed 4030.3526
# At Epoch: 616000.0
# Loss 2.9928
# time elapsed 4049.3727
# At Epoch: 617000.0
# Loss 2.7728
# time elapsed 4068.9667
# At Epoch: 618000.0
# Loss 3.2915
# time elapsed 4088.2620
# At Epoch: 619000.0
# Loss 2.9298
# time elapsed 4107.8310
# At Epoch: 620000.0
# Loss 2.9616
# time elapsed 4127.2635
# At Epoch: 621000.0
# Loss 2.9927
# time elapsed 4146.9799
# At Epoch: 622000.0
# Loss 3.0606
# time elapsed 4166.3628
# At Epoch: 623000.0
# Loss 2.9181
# time elapsed 4185.6254
# At Epoch: 624000.0
# Loss 2.8937
# time elapsed 4204.9825
# At Epoch: 625000.0
# Loss 3.5758
# time elapsed 4224.3683
# At Epoch: 626000.0
# Loss 3.1852
# time elapsed 4243.7907
# At Epoch: 627000.0
# Loss 3.1305
# time elapsed 4262.9789
# At Epoch: 628000.0
# Loss 2.5917
# time elapsed 4282.5776
# At Epoch: 629000.0
# Loss 3.0468
# time elapsed 4301.7939
# At Epoch: 630000.0
# Loss 3.2719
# time elapsed 4321.0993
# At Epoch: 631000.0
# Loss 3.0222
# time elapsed 4340.5970
# At Epoch: 632000.0
# Loss 3.1734
# time elapsed 4361.1340
# At Epoch: 633000.0
# Loss 2.9597
# time elapsed 4380.4541
# At Epoch: 634000.0
# Loss 3.0464
# time elapsed 4399.7762
# At Epoch: 635000.0
# Loss 3.0976
# time elapsed 4419.2127
# At Epoch: 636000.0
# Loss 2.9221
# time elapsed 4438.5818
# At Epoch: 637000.0
# Loss 2.8861
# time elapsed 4457.9219
# At Epoch: 638000.0
# Loss 2.9689
# time elapsed 4477.2738
# At Epoch: 639000.0
# Loss 2.8636
# time elapsed 4496.5708
# At Epoch: 640000.0
# Loss 3.3596
# time elapsed 4516.7998
# At Epoch: 641000.0
# Loss 3.1669
# time elapsed 4536.8957
# At Epoch: 642000.0
# Loss 3.0123
# time elapsed 4556.3180
# At Epoch: 643000.0
# Loss 3.1310
# time elapsed 4576.6954
# At Epoch: 644000.0
# Loss 2.9724
# time elapsed 4596.1691
# At Epoch: 645000.0
# Loss 2.8696
# time elapsed 4615.8319
# At Epoch: 646000.0
# Loss 2.5005
# time elapsed 4635.0789
# At Epoch: 647000.0
# Loss 2.8969
# time elapsed 4654.3711
# At Epoch: 648000.0
# Loss 2.6998
# time elapsed 4674.6251
# At Epoch: 649000.0
# Loss 2.9195
# time elapsed 4693.8226
# At Epoch: 650000.0
# Loss 2.6401
# time elapsed 4712.9524
# At Epoch: 651000.0
# Loss 2.9376
# time elapsed 4732.4095
# At Epoch: 652000.0
# Loss 3.2206
# time elapsed 4751.8696
# At Epoch: 653000.0
# Loss 3.1199
# time elapsed 4771.3204
# At Epoch: 654000.0
# Loss 2.9850
# time elapsed 4790.7833
# At Epoch: 655000.0
# Loss 3.0422
# time elapsed 4810.0691
# At Epoch: 656000.0
# Loss 3.0237
# time elapsed 4829.4280
# At Epoch: 657000.0
# Loss 3.0629
# time elapsed 4849.9665
# At Epoch: 658000.0
# Loss 3.1503
# time elapsed 4869.9413
# At Epoch: 659000.0
# Loss 3.0210
# time elapsed 4889.2905
# At Epoch: 660000.0
# Loss 3.0500
# time elapsed 4908.5164
# At Epoch: 661000.0
# Loss 3.2462
# time elapsed 4927.6629
# At Epoch: 662000.0
# Loss 2.9260
# time elapsed 4946.7444
# At Epoch: 663000.0
# Loss 3.2313
# time elapsed 4966.0126
# At Epoch: 664000.0
# Loss 3.0122
# time elapsed 4985.3950
# At Epoch: 665000.0
# Loss 3.0444
# time elapsed 5004.5267
# At Epoch: 666000.0
# Loss 3.1318
# time elapsed 5023.8926
# At Epoch: 667000.0
# Loss 2.9998
# time elapsed 5043.0829
# At Epoch: 668000.0
# Loss 3.0544
# time elapsed 5062.1812
# At Epoch: 669000.0
# Loss 3.2834
# time elapsed 5081.3195
# At Epoch: 670000.0
# Loss 3.0973
# time elapsed 5100.4891
# At Epoch: 671000.0
# Loss 3.1861
# time elapsed 5119.8838
# At Epoch: 672000.0
# Loss 2.8554
# time elapsed 5139.0231
# At Epoch: 673000.0
# Loss 3.1715
# time elapsed 5158.9602
# At Epoch: 674000.0
# Loss 3.6245
# time elapsed 5178.3606
# At Epoch: 675000.0
# Loss 3.0632
# time elapsed 5197.6400
# At Epoch: 676000.0
# Loss 2.8957
# time elapsed 5216.8659
# At Epoch: 677000.0
# Loss 3.1625
# time elapsed 5236.1662
# At Epoch: 678000.0
# Loss 2.9648
# time elapsed 5255.4762
# At Epoch: 679000.0
# Loss 3.0823
# time elapsed 5274.7598
# At Epoch: 680000.0
# Loss 2.8142
# time elapsed 5294.0727
# At Epoch: 681000.0
# Loss 3.0409
# time elapsed 5313.4651
# At Epoch: 682000.0
# Loss 2.8947
# time elapsed 5333.4510
# At Epoch: 683000.0
# Loss 2.6196
# time elapsed 5352.8132
# At Epoch: 684000.0
# Loss 2.9134
# time elapsed 5372.1482
# At Epoch: 685000.0
# Loss 2.9601
# time elapsed 5391.4381
# At Epoch: 686000.0
# Loss 3.0401
# time elapsed 5411.6381
# At Epoch: 687000.0
# Loss 3.1117
# time elapsed 5431.8303
# At Epoch: 688000.0
# Loss 2.7669
# time elapsed 5451.2667
# At Epoch: 689000.0
# Loss 2.8308
# time elapsed 5470.9721
# At Epoch: 690000.0
# Loss 3.1994
# time elapsed 5490.9734
# At Epoch: 691000.0
# Loss 3.3695
# time elapsed 5510.4949
# At Epoch: 692000.0
# Loss 2.9451
# time elapsed 5529.5652
# At Epoch: 693000.0
# Loss 3.0660
# time elapsed 5549.2128
# At Epoch: 694000.0
# Loss 2.9968
# time elapsed 5568.7049
# At Epoch: 695000.0
# Loss 3.0312
# time elapsed 5588.0139
# At Epoch: 696000.0
# Loss 2.9169
# time elapsed 5607.6282
# At Epoch: 697000.0
# Loss 2.9609
# time elapsed 5626.9133
# At Epoch: 698000.0
# Loss 3.0209
# time elapsed 5646.3653
# At Epoch: 699000.0
# Loss 2.9526
# time elapsed 5665.4862
# At Epoch: 700000.0
# Loss 2.7182
# time elapsed 5685.4721
# At Epoch: 701000.0
# Loss 3.4544
# time elapsed 5704.7790
# At Epoch: 702000.0
# Loss 2.7672
# time elapsed 5724.0784
# At Epoch: 703000.0
# Loss 3.0068
# time elapsed 5743.4422
# At Epoch: 704000.0
# Loss 3.0538
# time elapsed 5763.0912
# At Epoch: 705000.0
# Loss 2.9782
# time elapsed 5782.7879
# At Epoch: 706000.0
# Loss 3.1283
# time elapsed 5802.1100
# At Epoch: 707000.0
# Loss 2.8281
# time elapsed 5821.3673
# At Epoch: 708000.0
# Loss 2.9014
# time elapsed 5840.6670
# At Epoch: 709000.0
# Loss 2.6139
# time elapsed 5859.9555
# At Epoch: 710000.0
# Loss 2.8837
# time elapsed 5879.3459
# At Epoch: 711000.0
# Loss 3.0808
# time elapsed 5898.7326
# At Epoch: 712000.0
# Loss 2.8774
# time elapsed 5918.2482
# At Epoch: 713000.0
# Loss 3.0944
# time elapsed 5937.5948
# At Epoch: 714000.0
# Loss 2.8673
# time elapsed 5956.9187
# At Epoch: 715000.0
# Loss 3.0382
# time elapsed 5976.3020
# At Epoch: 716000.0
# Loss 2.9460
# time elapsed 5995.6193
# At Epoch: 717000.0
# Loss 3.0634
# time elapsed 6015.2330
# At Epoch: 718000.0
# Loss 2.9278
# time elapsed 6034.5269
# At Epoch: 719000.0
# Loss 3.0794
# time elapsed 6053.8210
# At Epoch: 720000.0
# Loss 2.9188
# time elapsed 6073.3006
# At Epoch: 721000.0
# Loss 3.0978
# time elapsed 6093.3564
# At Epoch: 722000.0
# Loss 3.0004
# time elapsed 6113.0592
# At Epoch: 723000.0
# Loss 2.7015
# time elapsed 6132.3735
# At Epoch: 724000.0
# Loss 3.2598
# time elapsed 6152.1439
# At Epoch: 725000.0
# Loss 2.9024
# time elapsed 6171.6905
# At Epoch: 726000.0
# Loss 3.2313
# time elapsed 6191.5199
# At Epoch: 727000.0
# Loss 2.9044
# time elapsed 6210.8693
# At Epoch: 728000.0
# Loss 2.9072
# time elapsed 6230.9512
# At Epoch: 729000.0
# Loss 3.2125
# time elapsed 6250.0366
# At Epoch: 730000.0
# Loss 2.9290
# time elapsed 6269.1898
# At Epoch: 731000.0
# Loss 3.0676
# time elapsed 6288.5590
# At Epoch: 732000.0
# Loss 3.0508
# time elapsed 6307.9957
# At Epoch: 733000.0
# Loss 2.9674
# time elapsed 6327.9637
# At Epoch: 734000.0
# Loss 2.9489
# time elapsed 6348.1971
# At Epoch: 735000.0
# Loss 3.0854
# time elapsed 6367.5078
# At Epoch: 736000.0
# Loss 3.0614
# time elapsed 6387.0835
# At Epoch: 737000.0
# Loss 3.2914
# time elapsed 6406.5583
# At Epoch: 738000.0
# Loss 2.9625
# time elapsed 6426.0102
# At Epoch: 739000.0
# Loss 2.8875
# time elapsed 6445.3188
# At Epoch: 740000.0
# Loss 2.7141
# time elapsed 6464.5701
# At Epoch: 741000.0
# Loss 2.9369
# time elapsed 6483.7706
# At Epoch: 742000.0
# Loss 2.9951
# time elapsed 6503.0196
# At Epoch: 743000.0
# Loss 2.9134
# time elapsed 6522.6599
# At Epoch: 744000.0
# Loss 3.0520
# time elapsed 6541.6860
# At Epoch: 745000.0
# Loss 2.8882
# time elapsed 6561.0695
# At Epoch: 746000.0
# Loss 2.6472
# time elapsed 6580.2888
# At Epoch: 747000.0
# Loss 2.9614
# time elapsed 6599.3709
# At Epoch: 748000.0
# Loss 3.0143
# time elapsed 6618.6260
# At Epoch: 749000.0
# Loss 2.9746
# time elapsed 6638.1680
# At Epoch: 750000.0
# Loss 3.1841
# time elapsed 6658.0450
# At Epoch: 751000.0
# Loss 3.0358
# time elapsed 6677.7542
# At Epoch: 752000.0
# Loss 3.3909
# time elapsed 6697.4297
# At Epoch: 753000.0
# Loss 2.8839
# time elapsed 6716.7848
# At Epoch: 754000.0
# Loss 2.8872
# time elapsed 6736.3501
# At Epoch: 755000.0
# Loss 3.0233
# time elapsed 6755.8682
# At Epoch: 756000.0
# Loss 3.1609
# time elapsed 6776.6985
# At Epoch: 757000.0
# Loss 2.9051
# time elapsed 6796.1253
# At Epoch: 758000.0
# Loss 3.1337
# time elapsed 6815.5094
# At Epoch: 759000.0
# Loss 2.8660
# time elapsed 6834.8846
# At Epoch: 760000.0
# Loss 2.9431
# time elapsed 6854.0944
# At Epoch: 761000.0
# Loss 3.0516
# time elapsed 6873.7222
# At Epoch: 762000.0
# Loss 2.9011
# time elapsed 6892.8811
# At Epoch: 763000.0
# Loss 3.0714
# time elapsed 6912.0765
# At Epoch: 764000.0
# Loss 3.0856
# time elapsed 6931.2874
# At Epoch: 765000.0
# Loss 3.0060
# time elapsed 6950.5032
# At Epoch: 766000.0
# Loss 2.9459
# time elapsed 6969.7897
# At Epoch: 767000.0
# Loss 2.8727
# time elapsed 6989.4412
# At Epoch: 768000.0
# Loss 3.0500
# time elapsed 7008.7414
# At Epoch: 769000.0
# Loss 2.9196
# time elapsed 7028.1758
# At Epoch: 770000.0
# Loss 3.1379
# time elapsed 7047.4183
# At Epoch: 771000.0
# Loss 2.9075
# time elapsed 7066.5492
# At Epoch: 772000.0
# Loss 2.8867
# time elapsed 7085.7685
# At Epoch: 773000.0
# Loss 3.1939
# time elapsed 7105.0894
# At Epoch: 774000.0
# Loss 2.9148
# time elapsed 7124.4743
# At Epoch: 775000.0
# Loss 2.8067
# time elapsed 7143.7831
# At Epoch: 776000.0
# Loss 3.1053
# time elapsed 7163.1827
# At Epoch: 777000.0
# Loss 2.9701
# time elapsed 7182.3731
# At Epoch: 778000.0
# Loss 2.9737
# time elapsed 7201.6812
# At Epoch: 779000.0
# Loss 3.6557
# time elapsed 7221.5608
# At Epoch: 780000.0
# Loss 3.0130
# time elapsed 7241.2940
# At Epoch: 781000.0
# Loss 3.0007
# time elapsed 7261.2870
# At Epoch: 782000.0
# Loss 3.1191
# time elapsed 7281.2216
# At Epoch: 783000.0
# Loss 2.8883
# time elapsed 7300.6177
# At Epoch: 784000.0
# Loss 3.0108
# time elapsed 7319.9098
# At Epoch: 785000.0
# Loss 2.9777
# time elapsed 7339.3663
# At Epoch: 786000.0
# Loss 3.3438
# time elapsed 7358.8433
# At Epoch: 787000.0
# Loss 2.9538
# time elapsed 7378.2107
# At Epoch: 788000.0
# Loss 2.9832
# time elapsed 7397.6465
# At Epoch: 789000.0
# Loss 2.8956
# time elapsed 7417.1609
# At Epoch: 790000.0
# Loss 3.0020
# time elapsed 7436.4753
# At Epoch: 791000.0
# Loss 2.8916
# time elapsed 7455.8557
# At Epoch: 792000.0
# Loss 3.0856
# time elapsed 7475.5915
# At Epoch: 793000.0
# Loss 3.1398
# time elapsed 7495.0272
# At Epoch: 794000.0
# Loss 3.0862
# time elapsed 7514.4212
# At Epoch: 795000.0
# Loss 3.0252
# time elapsed 7533.8656
# At Epoch: 796000.0
# Loss 3.0889
# time elapsed 7553.4027
# At Epoch: 797000.0
# Loss 3.1692
# time elapsed 7573.2292
# At Epoch: 798000.0
# Loss 3.1206
# time elapsed 7592.6455
# At Epoch: 799000.0
# Loss 3.1429
# time elapsed 7612.1447
# At Epoch: 800000.0
# Loss 3.0170
# time elapsed 7631.5324
# At Epoch: 801000.0
# Loss 2.9301
# time elapsed 7651.0978
# At Epoch: 802000.0
# Loss 2.9832
# time elapsed 7670.3897
# At Epoch: 803000.0
# Loss 2.6946
# time elapsed 7689.8629
# At Epoch: 804000.0
# Loss 3.1658
# time elapsed 7708.9199
# At Epoch: 805000.0
# Loss 3.1551
# time elapsed 7728.4996
# At Epoch: 806000.0
# Loss 2.9543
# time elapsed 7747.9164
# At Epoch: 807000.0
# Loss 3.0129
# time elapsed 7767.7200
# At Epoch: 808000.0
# Loss 3.1840
# time elapsed 7786.9143
# At Epoch: 809000.0
# Loss 3.1146
# time elapsed 7806.0523
# At Epoch: 810000.0
# Loss 2.9046
# time elapsed 7825.4070
# At Epoch: 811000.0
# Loss 2.7532
# time elapsed 7844.6907
# At Epoch: 812000.0
# Loss 2.6536
# time elapsed 7863.9584
# At Epoch: 813000.0
# Loss 3.0649
# time elapsed 7883.2420
# At Epoch: 814000.0
# Loss 3.1228
# time elapsed 7902.5818
# At Epoch: 815000.0
# Loss 2.7378
# time elapsed 7921.7544
# At Epoch: 816000.0
# Loss 3.0516
# time elapsed 7940.8617
# At Epoch: 817000.0
# Loss 3.1058
# time elapsed 7960.3872
# At Epoch: 818000.0
# Loss 2.9215
# time elapsed 7979.4048
# At Epoch: 819000.0
# Loss 3.0237
# time elapsed 7998.4585
# At Epoch: 820000.0
# Loss 3.0251
# time elapsed 8017.6249
# At Epoch: 821000.0
# Loss 2.8636
# time elapsed 8036.7608
# At Epoch: 822000.0
# Loss 2.9221
# time elapsed 8055.8860
# At Epoch: 823000.0
# Loss 3.2207
# time elapsed 8076.3259
# At Epoch: 824000.0
# Loss 2.8304
# time elapsed 8095.5866
# At Epoch: 825000.0
# Loss 3.0441
# time elapsed 8115.4383
# At Epoch: 826000.0
# Loss 2.9872
# time elapsed 8135.3263
# At Epoch: 827000.0
# Loss 3.0240
# time elapsed 8155.0634
# At Epoch: 828000.0
# Loss 2.8567
# time elapsed 8174.6693
# At Epoch: 829000.0
# Loss 3.0329
# time elapsed 8194.4472
# At Epoch: 830000.0
# Loss 2.8046
# time elapsed 8213.7880
# At Epoch: 831000.0
# Loss 2.4721
# time elapsed 8233.1282
# At Epoch: 832000.0
# Loss 2.8522
# time elapsed 8252.8985
# At Epoch: 833000.0
# Loss 3.1269
# time elapsed 8273.1330
# At Epoch: 834000.0
# Loss 2.8546
# time elapsed 8292.3713
# At Epoch: 835000.0
# Loss 3.0551
# time elapsed 8311.5933
# At Epoch: 836000.0
# Loss 3.0385
# time elapsed 8330.7371
# At Epoch: 837000.0
# Loss 3.1403
# time elapsed 8349.9074
# At Epoch: 838000.0
# Loss 3.1242
# time elapsed 8369.1552
# At Epoch: 839000.0
# Loss 2.8349
# time elapsed 8388.4104
# At Epoch: 840000.0
# Loss 2.9668
# time elapsed 8407.5897
# At Epoch: 841000.0
# Loss 3.0202
# time elapsed 8426.7564
# At Epoch: 842000.0
# Loss 3.0210
# time elapsed 8445.9520
# At Epoch: 843000.0
# Loss 2.8903
# time elapsed 8465.2023
# At Epoch: 844000.0
# Loss 2.9199
# time elapsed 8484.4178
# At Epoch: 845000.0
# Loss 3.6178
# time elapsed 8503.8082
# At Epoch: 846000.0
# Loss 2.9401
# time elapsed 8523.4638
# At Epoch: 847000.0
# Loss 2.9735
# time elapsed 8542.5715
# At Epoch: 848000.0
# Loss 2.8531
# time elapsed 8561.7365
# At Epoch: 849000.0
# Loss 3.1002
# time elapsed 8580.9900
# At Epoch: 850000.0
# Loss 3.3400
# time elapsed 8600.1446
# At Epoch: 851000.0
# Loss 2.9627
# time elapsed 8619.2487
# At Epoch: 852000.0
# Loss 3.2371
# time elapsed 8638.7323
# At Epoch: 853000.0
# Loss 3.4135
# time elapsed 8658.1753
# At Epoch: 854000.0
# Loss 3.0034
# time elapsed 8677.5275
# At Epoch: 855000.0
# Loss 3.0101
# time elapsed 8696.6997
# At Epoch: 856000.0
# Loss 3.0510
# time elapsed 8716.0816
# At Epoch: 857000.0
# Loss 3.2558
# time elapsed 8735.6460
# At Epoch: 858000.0
# Loss 2.9754
# time elapsed 8754.9833
# At Epoch: 859000.0
# Loss 2.9231
# time elapsed 8774.3764
# At Epoch: 860000.0
# Loss 3.3073
# time elapsed 8793.7311
# At Epoch: 861000.0
# Loss 2.8868
# time elapsed 8813.0330
# At Epoch: 862000.0
# Loss 3.2441
# time elapsed 8832.3175
# At Epoch: 863000.0
# Loss 3.2085
# time elapsed 8852.2889
# At Epoch: 864000.0
# Loss 2.9187
# time elapsed 8871.5119
# At Epoch: 865000.0
# Loss 2.7362
# time elapsed 8890.7669
# At Epoch: 866000.0
# Loss 2.8241
# time elapsed 8910.4189
# At Epoch: 867000.0
# Loss 2.8173
# time elapsed 8929.8072
# At Epoch: 868000.0
# Loss 2.7985
# time elapsed 8949.6901
# At Epoch: 869000.0
# Loss 3.0638
# time elapsed 8969.0518
# At Epoch: 870000.0
# Loss 3.0494
# time elapsed 8988.3854
# At Epoch: 871000.0
# Loss 2.9990
# time elapsed 9007.8692
# At Epoch: 872000.0
# Loss 3.0540
# time elapsed 9027.8354
# At Epoch: 873000.0
# Loss 2.8170
# time elapsed 9048.9102
# At Epoch: 874000.0
# Loss 3.0366
# time elapsed 9069.0785
# At Epoch: 875000.0
# Loss 2.8885
# time elapsed 9089.0950
# At Epoch: 876000.0
# Loss 3.1424
# time elapsed 9108.7287
# At Epoch: 877000.0
# Loss 3.0683
# time elapsed 9128.5453
# At Epoch: 878000.0
# Loss 3.1583
# time elapsed 9148.0700
# At Epoch: 879000.0
# Loss 2.9296
# time elapsed 9167.6477
# At Epoch: 880000.0
# Loss 2.9904
# time elapsed 9187.3637
# At Epoch: 881000.0
# Loss 3.0627
# time elapsed 9206.5252
# At Epoch: 882000.0
# Loss 3.4990
# time elapsed 9226.8080
# At Epoch: 883000.0
# Loss 2.9818
# time elapsed 9246.1304
# At Epoch: 884000.0
# Loss 3.0696
# time elapsed 9265.8794
# At Epoch: 885000.0
# Loss 3.1079
# time elapsed 9285.0426
# At Epoch: 886000.0
# Loss 3.0653
# time elapsed 9304.3529
# At Epoch: 887000.0
# Loss 3.0586
# time elapsed 9323.7832
# At Epoch: 888000.0
# Loss 3.0099
# time elapsed 9343.0549
# At Epoch: 889000.0
# Loss 3.0295
# time elapsed 9362.4776
# At Epoch: 890000.0
# Loss 3.1469
# time elapsed 9381.9590
# At Epoch: 891000.0
# Loss 2.9741
# time elapsed 9401.3038
# At Epoch: 892000.0
# Loss 3.0296
# time elapsed 9420.5881
# At Epoch: 893000.0
# Loss 3.2348
# time elapsed 9439.8305
# At Epoch: 894000.0
# Loss 2.9438
# time elapsed 9459.8721
# At Epoch: 895000.0
# Loss 3.0824
# time elapsed 9479.3601
# At Epoch: 896000.0
# Loss 3.3619
# time elapsed 9498.6379
# At Epoch: 897000.0
# Loss 2.9383
# time elapsed 9518.0499
# At Epoch: 898000.0
# Loss 2.8321
# time elapsed 9537.5200
# At Epoch: 899000.0
# Loss 2.5388
# time elapsed 9556.9364
# At Epoch: 900000.0
# Loss 2.9375
# time elapsed 9576.3002
# At Epoch: 901000.0
# Loss 3.0417
# time elapsed 9595.9753
# At Epoch: 902000.0
# Loss 2.8645
# time elapsed 9615.6543
# At Epoch: 903000.0
# Loss 3.1119
# time elapsed 9634.9842
# At Epoch: 904000.0
# Loss 3.6913
# time elapsed 9655.0497
# At Epoch: 905000.0
# Loss 3.0961
# time elapsed 9674.4767
# At Epoch: 906000.0
# Loss 2.9812
# time elapsed 9693.9147
# At Epoch: 907000.0
# Loss 3.4956
# time elapsed 9713.3775
# At Epoch: 908000.0
# Loss 3.3788
# time elapsed 9732.5514
# At Epoch: 909000.0
# Loss 2.9436
# time elapsed 9751.8113
# At Epoch: 910000.0
# Loss 3.2105
# time elapsed 9770.8348
# At Epoch: 911000.0
# Loss 2.8208
# time elapsed 9790.2013
# At Epoch: 912000.0
# Loss 3.0311
# time elapsed 9809.2576
# At Epoch: 913000.0
# Loss 2.9613
# time elapsed 9828.4507
# At Epoch: 914000.0
# Loss 3.1558
# time elapsed 9847.5933
# At Epoch: 915000.0
# Loss 3.0760
# time elapsed 9866.7619
# At Epoch: 916000.0
# Loss 2.8788
# time elapsed 9886.5716
# At Epoch: 917000.0
# Loss 3.1583
# time elapsed 9905.9373
# At Epoch: 918000.0
# Loss 2.9732
# time elapsed 9926.2976
# At Epoch: 919000.0
# Loss 3.0892
# time elapsed 9947.0422
# At Epoch: 920000.0
# Loss 2.8815
# time elapsed 9966.4447
# At Epoch: 921000.0
# Loss 2.8801
# time elapsed 9986.3055
# At Epoch: 922000.0
# Loss 3.0431
# time elapsed 10005.8285
# At Epoch: 923000.0
# Loss 2.9877
# time elapsed 10025.4499
# At Epoch: 924000.0
# Loss 2.9418
# time elapsed 10045.0841
# At Epoch: 925000.0
# Loss 2.9465
# time elapsed 10064.3807
# At Epoch: 926000.0
# Loss 2.7247
# time elapsed 10083.9055
# At Epoch: 927000.0
# Loss 2.6671
# time elapsed 10103.3795
# At Epoch: 928000.0
# Loss 3.0905
# time elapsed 10122.8424
# At Epoch: 929000.0
# Loss 3.2226
# time elapsed 10142.1946
# At Epoch: 930000.0
# Loss 2.9149
# time elapsed 10161.5544
# At Epoch: 931000.0
# Loss 2.8453
# time elapsed 10181.1353
# At Epoch: 932000.0
# Loss 3.0631
# time elapsed 10200.5914
# At Epoch: 933000.0
# Loss 3.3348
# time elapsed 10220.1096
# At Epoch: 934000.0
# Loss 2.8336
# time elapsed 10239.4548
# At Epoch: 935000.0
# Loss 3.1048
# time elapsed 10258.5130
# At Epoch: 936000.0
# Loss 2.5274
# time elapsed 10277.5744
# At Epoch: 937000.0
# Loss 2.9321
# time elapsed 10297.3201
# At Epoch: 938000.0
# Loss 3.8459
# time elapsed 10317.0683
# At Epoch: 939000.0
# Loss 2.9954
# time elapsed 10336.1153
# At Epoch: 940000.0
# Loss 3.0405
# time elapsed 10355.3909
# At Epoch: 941000.0
# Loss 2.6829
# time elapsed 10374.5188
# At Epoch: 942000.0
# Loss 2.6930
# time elapsed 10393.8073
# At Epoch: 943000.0
# Loss 2.9197
# time elapsed 10413.1742
# At Epoch: 944000.0
# Loss 3.3042
# time elapsed 10433.0059
# At Epoch: 945000.0
# Loss 2.9689
# time elapsed 10452.3758
# At Epoch: 946000.0
# Loss 2.8797
# time elapsed 10471.6077
# At Epoch: 947000.0
# Loss 2.7541
# time elapsed 10491.8380
# At Epoch: 948000.0
# Loss 3.1962
# time elapsed 10511.0956
# At Epoch: 949000.0
# Loss 2.9384
# time elapsed 10530.5528
# At Epoch: 950000.0
# Loss 2.8587
# time elapsed 10549.6592
# At Epoch: 951000.0
# Loss 2.9873
# time elapsed 10568.8468
# At Epoch: 952000.0
# Loss 3.1289
# time elapsed 10587.9160
# At Epoch: 953000.0
# Loss 2.8569
# time elapsed 10607.3134
# At Epoch: 954000.0
# Loss 3.0257
# time elapsed 10626.9808
# At Epoch: 955000.0
# Loss 3.0566
# time elapsed 10646.2579
# At Epoch: 956000.0
# Loss 3.2481
# time elapsed 10665.7587
# At Epoch: 957000.0
# Loss 2.7893
# time elapsed 10685.1013
# At Epoch: 958000.0
# Loss 2.9886
# time elapsed 10704.5197
# At Epoch: 959000.0
# Loss 2.9724
# time elapsed 10724.0896
# At Epoch: 960000.0
# Loss 2.7385
# time elapsed 10743.4595
# At Epoch: 961000.0
# Loss 3.0327
# time elapsed 10762.7800
# At Epoch: 962000.0
# Loss 3.1629
# time elapsed 10782.0413
# At Epoch: 963000.0
# Loss 2.9954
# time elapsed 10801.3534
# At Epoch: 964000.0
# Loss 2.9800
# time elapsed 10821.5615
# At Epoch: 965000.0
# Loss 2.9067
# time elapsed 10841.3158
# At Epoch: 966000.0
# Loss 2.9346
# time elapsed 10861.4775
# At Epoch: 967000.0
# Loss 2.7594
# time elapsed 10881.5600
# At Epoch: 968000.0
# Loss 3.2694
# time elapsed 10901.1654
# At Epoch: 969000.0
# Loss 2.7393
# time elapsed 10920.5457
# At Epoch: 970000.0
# Loss 3.0874
# time elapsed 10939.9350
# At Epoch: 971000.0
# Loss 3.3016
# time elapsed 10959.3305
# At Epoch: 972000.0
# Loss 2.9850
# time elapsed 10978.5927
# At Epoch: 973000.0
# Loss 3.0253
# time elapsed 10997.8555
# At Epoch: 974000.0
# Loss 2.8930
# time elapsed 11017.1263
# At Epoch: 975000.0
# Loss 2.9459
# time elapsed 11037.2294
# At Epoch: 976000.0
# Loss 2.8454
# time elapsed 11056.6652
# At Epoch: 977000.0
# Loss 3.2412
# time elapsed 11076.0990
# At Epoch: 978000.0
# Loss 3.5994
# time elapsed 11095.4131
# At Epoch: 979000.0
# Loss 3.0324
# time elapsed 11114.7309
# At Epoch: 980000.0
# Loss 2.8986
# time elapsed 11134.0099
# At Epoch: 981000.0
# Loss 2.8850
# time elapsed 11153.4953
# At Epoch: 982000.0
# Loss 2.9506
# time elapsed 11173.2362
# At Epoch: 983000.0
# Loss 3.1612
# time elapsed 11192.4860
# At Epoch: 984000.0
# Loss 2.8784
# time elapsed 11211.9658
# At Epoch: 985000.0
# Loss 2.9688
# time elapsed 11231.3840
# At Epoch: 986000.0
# Loss 2.9229
# time elapsed 11250.6721
# At Epoch: 987000.0
# Loss 2.9140
# time elapsed 11270.2847
# At Epoch: 988000.0
# Loss 2.9511
# time elapsed 11289.8529
# At Epoch: 989000.0
# Loss 3.2242
# time elapsed 11309.1669
# At Epoch: 990000.0
# Loss 2.9896
# time elapsed 11328.5226
# At Epoch: 991000.0
# Loss 3.0853
# time elapsed 11347.8493
# At Epoch: 992000.0
# Loss 3.0103
# time elapsed 11367.3008
# At Epoch: 993000.0
# Loss 3.1435
# time elapsed 11386.6597
# At Epoch: 994000.0
# Loss 3.1423
# time elapsed 11405.9769
# At Epoch: 995000.0
# Loss 2.8291
# time elapsed 11425.3609
# At Epoch: 996000.0
# Loss 2.8508
# time elapsed 11444.9118
# At Epoch: 997000.0
# Loss 2.8892
# time elapsed 11464.2950
# At Epoch: 998000.0
# Loss 3.1389
# time elapsed 11483.6880
# At Epoch: 999000.0
# Loss 2.9457
# time elapsed 11503.0065
# At Epoch: 1000000.0
# Loss 2.8775
# time elapsed 11522.4739
# At Epoch: 1001000.0
# Loss 2.7442
# time elapsed 11541.7506
# At Epoch: 1002000.0
# Loss 2.8058
# time elapsed 11560.9803
# At Epoch: 1003000.0
# Loss 3.4348
# time elapsed 11580.1090
# At Epoch: 1004000.0
# Loss 3.1080
# time elapsed 11599.4599
# At Epoch: 1005000.0
# Loss 3.2311
# time elapsed 11619.1823
# At Epoch: 1006000.0
# Loss 3.0271
# time elapsed 11638.2793
# At Epoch: 1007000.0
# Loss 3.0243
# time elapsed 11658.0105
# At Epoch: 1008000.0
# Loss 3.0248
# time elapsed 11677.2107
# At Epoch: 1009000.0
# Loss 2.9001
# time elapsed 11696.4042
# At Epoch: 1010000.0
# Loss 2.6284
# time elapsed 11715.8536
# At Epoch: 1011000.0
# Loss 3.0074
# time elapsed 11735.4539
# At Epoch: 1012000.0
# Loss 2.8626
# time elapsed 11755.3306
# At Epoch: 1013000.0
# Loss 2.9228
# time elapsed 11774.8374
# At Epoch: 1014000.0
# Loss 3.0530
# time elapsed 11794.3572
# At Epoch: 1015000.0
# Loss 2.9266
# time elapsed 11813.5236
# At Epoch: 1016000.0
# Loss 2.9246
# time elapsed 11832.5901
# At Epoch: 1017000.0
# Loss 2.8810
# time elapsed 11851.6546
# At Epoch: 1018000.0
# Loss 2.9882
# time elapsed 11870.7110
# At Epoch: 1019000.0
# Loss 3.4012
# time elapsed 11889.9895
# At Epoch: 1020000.0
# Loss 2.8464
# time elapsed 11909.1442
# At Epoch: 1021000.0
# Loss 2.9913
# time elapsed 11928.4331
# At Epoch: 1022000.0
# Loss 2.9649
# time elapsed 11947.5233
# At Epoch: 1023000.0
# Loss 2.7080
# time elapsed 11966.7119
# At Epoch: 1024000.0
# Loss 3.3483
# time elapsed 11986.1007
# At Epoch: 1025000.0
# Loss 3.0975
# time elapsed 12005.2706
# At Epoch: 1026000.0
# Loss 2.8761
# time elapsed 12024.3902
# At Epoch: 1027000.0
# Loss 3.0020
# time elapsed 12043.5033
# At Epoch: 1028000.0
# Loss 2.9670
# time elapsed 12062.7518
# At Epoch: 1029000.0
# Loss 2.9908
# time elapsed 12082.1296
# At Epoch: 1030000.0
# Loss 3.3704
# time elapsed 12101.4696
# At Epoch: 1031000.0
# Loss 2.7275
# time elapsed 12120.9378
# At Epoch: 1032000.0
# Loss 2.9323
# time elapsed 12140.3520
# At Epoch: 1033000.0
# Loss 3.3307
# time elapsed 12160.0735
# At Epoch: 1034000.0
# Loss 2.8733
# time elapsed 12179.2114
# At Epoch: 1035000.0
# Loss 2.9190
# time elapsed 12198.4267
# At Epoch: 1036000.0
# Loss 2.8465
# time elapsed 12217.6124
# At Epoch: 1037000.0
# Loss 2.9561
# time elapsed 12237.0021
# At Epoch: 1038000.0
# Loss 2.8625
# time elapsed 12256.3220
# At Epoch: 1039000.0
# Loss 3.0567
# time elapsed 12275.6108
# At Epoch: 1040000.0
# Loss 2.8503
# time elapsed 12294.9980
# At Epoch: 1041000.0
# Loss 3.2771
# time elapsed 12314.4111
# At Epoch: 1042000.0
# Loss 3.4057
# time elapsed 12333.7804
# At Epoch: 1043000.0
# Loss 3.2052
# time elapsed 12353.1809
# At Epoch: 1044000.0
# Loss 3.0455
# time elapsed 12372.4887
# At Epoch: 1045000.0
# Loss 2.4982
# time elapsed 12391.9313
# At Epoch: 1046000.0
# Loss 3.1765
# time elapsed 12411.7245
# At Epoch: 1047000.0
# Loss 3.0163
# time elapsed 12432.4265
# At Epoch: 1048000.0
# Loss 2.9540
# time elapsed 12451.8907
# At Epoch: 1049000.0
# Loss 3.0939
# time elapsed 12471.3821
# At Epoch: 1050000.0
# Loss 2.9794
# time elapsed 12490.8675
# At Epoch: 1051000.0
# Loss 2.8698
# time elapsed 12510.5046
# At Epoch: 1052000.0
# Loss 3.0424
# time elapsed 12530.0065
# At Epoch: 1053000.0
# Loss 2.9835
# time elapsed 12549.3005
# At Epoch: 1054000.0
# Loss 3.4359
# time elapsed 12568.9349
# At Epoch: 1055000.0
# Loss 2.7879
# time elapsed 12588.2957
# At Epoch: 1056000.0
# Loss 3.2767
# time elapsed 12608.0053
# At Epoch: 1057000.0
# Loss 3.1595
# time elapsed 12627.9151
# At Epoch: 1058000.0
# Loss 2.8550
# time elapsed 12647.8088
# At Epoch: 1059000.0
# Loss 2.8608
# time elapsed 12667.1355
# At Epoch: 1060000.0
# Loss 2.6184
# time elapsed 12686.8113
# At Epoch: 1061000.0
# Loss 3.2051
# time elapsed 12705.9469
# At Epoch: 1062000.0
# Loss 3.1298
# time elapsed 12725.0585
# At Epoch: 1063000.0
# Loss 2.8718
# time elapsed 12744.4705
# At Epoch: 1064000.0
# Loss 2.6781
# time elapsed 12763.6413
# At Epoch: 1065000.0
# Loss 3.1186
# time elapsed 12782.8339
# At Epoch: 1066000.0
# Loss 2.7590
# time elapsed 12802.0175
# At Epoch: 1067000.0
# Loss 3.2153
# time elapsed 12821.2508
# At Epoch: 1068000.0
# Loss 3.5073
# time elapsed 12840.6246
# At Epoch: 1069000.0
# Loss 3.4493
# time elapsed 12859.7120
# At Epoch: 1070000.0
# Loss 3.0700
# time elapsed 12878.9532
# At Epoch: 1071000.0
# Loss 3.1420
# time elapsed 12898.0163
# At Epoch: 1072000.0
# Loss 2.9237
# time elapsed 12917.2929
# At Epoch: 1073000.0
# Loss 3.3435
# time elapsed 12936.4931
# At Epoch: 1074000.0
# Loss 3.0643
# time elapsed 12955.5955
# At Epoch: 1075000.0
# Loss 3.1556
# time elapsed 12975.2291
# At Epoch: 1076000.0
# Loss 3.1702
# time elapsed 12995.4462
# At Epoch: 1077000.0
# Loss 3.1942
# time elapsed 13014.7620
# At Epoch: 1078000.0
# Loss 2.9173
# time elapsed 13033.9670
# At Epoch: 1079000.0
# Loss 2.8178
# time elapsed 13053.2755
# At Epoch: 1080000.0
# Loss 3.0935
# time elapsed 13072.9920
# At Epoch: 1081000.0
# Loss 3.0299
# time elapsed 13092.0872
# At Epoch: 1082000.0
# Loss 2.7689
# time elapsed 13111.4814
# At Epoch: 1083000.0
# Loss 3.0018
# time elapsed 13130.7240
# At Epoch: 1084000.0
# Loss 2.9483
# time elapsed 13149.9955
# At Epoch: 1085000.0
# Loss 2.9264
# time elapsed 13169.2680
# At Epoch: 1086000.0
# Loss 3.1005
# time elapsed 13188.4952
# At Epoch: 1087000.0
# Loss 3.0085
# time elapsed 13207.8469
# At Epoch: 1088000.0
# Loss 3.2841
# time elapsed 13227.1753
# At Epoch: 1089000.0
# Loss 3.2146
# time elapsed 13246.4669
# At Epoch: 1090000.0
# Loss 3.1396
# time elapsed 13265.7010
# At Epoch: 1091000.0
# Loss 2.9965
# time elapsed 13284.9477
# At Epoch: 1092000.0
# Loss 3.0214
# time elapsed 13304.2085
# At Epoch: 1093000.0
# Loss 3.0850
# time elapsed 13323.5200
# At Epoch: 1094000.0
# Loss 3.2007
# time elapsed 13342.9515
# At Epoch: 1095000.0
# Loss 2.7110
# time elapsed 13363.0405
# At Epoch: 1096000.0
# Loss 2.9522
# time elapsed 13382.2358
# At Epoch: 1097000.0
# Loss 3.1867
# time elapsed 13401.6765
# At Epoch: 1098000.0
# Loss 2.6715
# time elapsed 13421.0410
# At Epoch: 1099000.0
# Loss 2.8766
# time elapsed 13440.5180
# At Epoch: 1100000.0
# Loss 3.3195
# time elapsed 13459.9235
# At Epoch: 1101000.0
# Loss 2.8840
# time elapsed 13479.4097
# At Epoch: 1102000.0
# Loss 3.0478
# time elapsed 13498.8108
# At Epoch: 1103000.0
# Loss 3.2103
# time elapsed 13518.7031
# At Epoch: 1104000.0
# Loss 2.8215
# time elapsed 13538.6762
# At Epoch: 1105000.0
# Loss 2.9487
# time elapsed 13558.4765
# At Epoch: 1106000.0
# Loss 3.1133
# time elapsed 13579.0087
# At Epoch: 1107000.0
# Loss 2.9175
# time elapsed 13600.4662
# At Epoch: 1108000.0
# Loss 3.0818
# time elapsed 13620.5045
# At Epoch: 1109000.0
# Loss 2.8960
# time elapsed 13640.4861
# At Epoch: 1110000.0
# Loss 2.7178
# time elapsed 13660.5245
# At Epoch: 1111000.0
# Loss 2.5849
# time elapsed 13680.5387
# At Epoch: 1112000.0
# Loss 2.7224
# time elapsed 13700.5508
# At Epoch: 1118000.0
# Loss 2.9403
# time elapsed 13820.7783
# At Epoch: 1119000.0
# Loss 3.0728
# time elapsed 13841.0740
# At Epoch: 1120000.0
# Loss 3.1282
# time elapsed 13860.9685
# At Epoch: 1121000.0
# Loss 3.0934
# time elapsed 13880.7479
# At Epoch: 1122000.0
# Loss 2.7921
# time elapsed 13900.4991
# At Epoch: 1123000.0
# Loss 2.9859
# time elapsed 13920.2719
# At Epoch: 1124000.0
# Loss 2.9863
# time elapsed 13939.9700
# At Epoch: 1125000.0
# Loss 2.9655
# time elapsed 13959.6651
# At Epoch: 1126000.0
# Loss 2.9264
# time elapsed 13979.3346
# At Epoch: 1127000.0
# Loss 2.8726
# time elapsed 13999.1447
# At Epoch: 1128000.0
# Loss 2.8741
# time elapsed 14018.8637
# At Epoch: 1129000.0
# Loss 2.8234
# time elapsed 14038.8467
# At Epoch: 1130000.0
# Loss 3.1476
# time elapsed 14058.7682
# At Epoch: 1131000.0
# Loss 3.0839
# time elapsed 14078.7738
# At Epoch: 1132000.0
# Loss 3.0528
# time elapsed 14098.7045
# At Epoch: 1133000.0
# Loss 3.1185
# time elapsed 14118.6583
# At Epoch: 1134000.0
# Loss 2.9583
# time elapsed 14138.6920
# At Epoch: 1135000.0
# Loss 3.1288
# time elapsed 14158.7595
# At Epoch: 1136000.0
# Loss 3.0948
# time elapsed 14178.6458
# At Epoch: 1137000.0
# Loss 3.0410
# time elapsed 14198.3227
# At Epoch: 1138000.0
# Loss 2.9036
# time elapsed 14217.9831
# At Epoch: 1139000.0
# Loss 3.0069
# time elapsed 14238.1812
# At Epoch: 1140000.0
# Loss 3.2450
# time elapsed 14258.2198
# At Epoch: 1141000.0
# Loss 3.0091
# time elapsed 14278.3279
# At Epoch: 1142000.0
# Loss 2.9680
# time elapsed 14298.4673
# At Epoch: 1143000.0
# Loss 2.9129
# time elapsed 14318.4777
# At Epoch: 1144000.0
# Loss 3.0106
# time elapsed 14341.4556
# At Epoch: 1145000.0
# Loss 3.1309
# time elapsed 14364.9195
# At Epoch: 1146000.0
# Loss 2.9252
# time elapsed 14387.4698
# At Epoch: 1147000.0
# Loss 2.8958
# time elapsed 14407.9388
# At Epoch: 1148000.0
# Loss 3.0323
# time elapsed 14428.6864
# At Epoch: 1149000.0
# Loss 3.1292
# time elapsed 14449.5422
# At Epoch: 1150000.0
# Loss 2.8486
# time elapsed 14469.9537
# At Epoch: 1151000.0
# Loss 2.7133
# time elapsed 14490.6969
# At Epoch: 1152000.0
# Loss 3.0423
# time elapsed 14510.6850
# At Epoch: 1153000.0
# Loss 2.7971
# time elapsed 14531.6045
# At Epoch: 1154000.0
# Loss 3.1481
# time elapsed 14551.3725
# At Epoch: 1155000.0
# Loss 3.1089
# time elapsed 14571.1687
# At Epoch: 1156000.0
# Loss 2.9186
# time elapsed 14590.8853
# At Epoch: 1157000.0
# Loss 3.0349
# time elapsed 14610.8757
# At Epoch: 1158000.0
# Loss 3.0550
# time elapsed 14631.1194
# At Epoch: 1159000.0
# Loss 3.1205
# time elapsed 14651.0380
# At Epoch: 1160000.0
# Loss 2.9566
# time elapsed 14672.0640
# At Epoch: 1161000.0
# Loss 3.1033
# time elapsed 14693.4018
# At Epoch: 1162000.0
# Loss 2.8790
# time elapsed 14713.5310
# At Epoch: 1163000.0
# Loss 3.2424
# time elapsed 14733.5184
# At Epoch: 1164000.0
# Loss 3.1440
# time elapsed 14753.4891
# At Epoch: 1165000.0
# Loss 3.1868
# time elapsed 14773.5066
# At Epoch: 1166000.0
# Loss 3.2631
# time elapsed 14793.4236
# At Epoch: 1167000.0
# Loss 2.8885
# time elapsed 14813.4126
# At Epoch: 1168000.0
# Loss 3.1625
# time elapsed 14833.1363
# At Epoch: 1169000.0
# Loss 3.1762
# time elapsed 14852.8635
# At Epoch: 1170000.0
# Loss 3.2426
# time elapsed 14872.8542
# At Epoch: 1171000.0
# Loss 2.8256
# time elapsed 14892.8476
# At Epoch: 1172000.0
# Loss 3.0895
# time elapsed 14912.8235
# At Epoch: 1173000.0
# Loss 3.4598
# time elapsed 14932.7872
# At Epoch: 1174000.0
# Loss 3.1454
# time elapsed 14952.8656
# At Epoch: 1175000.0
# Loss 3.2269
# time elapsed 14972.8702
# At Epoch: 1176000.0
# Loss 3.0172
# time elapsed 14992.8344
# At Epoch: 1177000.0
# Loss 2.7145
# time elapsed 15012.9722
# At Epoch: 1178000.0
# Loss 2.9531
# time elapsed 15033.0231
# At Epoch: 1179000.0
# Loss 2.7678
# time elapsed 15053.0379
# At Epoch: 1180000.0
# Loss 3.0395
# time elapsed 15072.9713
# At Epoch: 1181000.0
# Loss 2.6566
# time elapsed 15093.0153
# At Epoch: 1182000.0
# Loss 3.0592
# time elapsed 15113.1308
# At Epoch: 1183000.0
# Loss 2.7146
# time elapsed 15133.3558
# At Epoch: 1184000.0
# Loss 3.1270
# time elapsed 15153.2265
# At Epoch: 1185000.0
# Loss 2.9956
# time elapsed 15172.4493
# At Epoch: 1186000.0
# Loss 3.1560
# time elapsed 15191.6349
# At Epoch: 1187000.0
# Loss 2.8209
# time elapsed 15212.9208
# At Epoch: 1188000.0
# Loss 2.8095
# time elapsed 15232.2339
# At Epoch: 1189000.0
# Loss 2.8396
# time elapsed 15252.6355
# At Epoch: 1190000.0
# Loss 3.1637
# time elapsed 15275.2672
# At Epoch: 1191000.0
# Loss 3.1320
# time elapsed 15295.9335
# At Epoch: 1192000.0
# Loss 2.9196
# time elapsed 15318.7262
# At Epoch: 1193000.0
# Loss 3.1587
# time elapsed 15338.9594
# At Epoch: 1194000.0
# Loss 3.4289
# time elapsed 15358.1693
# At Epoch: 1195000.0
# Loss 2.9254
# time elapsed 15378.5022
# At Epoch: 1196000.0
# Loss 3.1963
# time elapsed 15398.1194
# At Epoch: 1197000.0
# Loss 3.1618
# time elapsed 15417.4605
# At Epoch: 1198000.0
# Loss 2.8784
# time elapsed 15437.0318
# At Epoch: 1199000.0
# Loss 2.8266
# time elapsed 15456.3732
# At Epoch: 1200000.0
# Loss 2.7493
# time elapsed 15475.3091
# At Epoch: 1201000.0
# Loss 2.9600
# time elapsed 15494.3404
# At Epoch: 1202000.0
# Loss 2.7268
# time elapsed 15513.5688
# At Epoch: 1203000.0
# Loss 3.0558
# time elapsed 15532.8534
# At Epoch: 1204000.0
# Loss 2.9056
# time elapsed 15551.7580
# At Epoch: 1205000.0
# Loss 3.1043
# time elapsed 15570.8459
# At Epoch: 1206000.0
# Loss 2.9280
# time elapsed 15590.0118
# At Epoch: 1207000.0
# Loss 2.9517
# time elapsed 15609.0308
# At Epoch: 1208000.0
# Loss 3.2847
# time elapsed 15628.0966
# At Epoch: 1209000.0
# Loss 2.7634
# time elapsed 15647.0555
# At Epoch: 1210000.0
# Loss 3.0175
# time elapsed 15665.9241
# At Epoch: 1211000.0
# Loss 3.1225
# time elapsed 15687.7415
# At Epoch: 1212000.0
# Loss 2.9697
# time elapsed 15708.0660

# %%
torch.save(model.state_dict(), "../../data/transformer_encoder_mlm_201025.pt")

# %%
print('done')
# Out:
# done
