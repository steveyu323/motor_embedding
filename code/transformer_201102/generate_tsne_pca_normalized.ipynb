# %%
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
import numpy as np
import pandas as pd

# %%
hn_dir = "../../out/201102/embedding/esm_models_normalized"
tuning_dir = ["t12_balanced","t12_kinesin","t12_motor_toolkit","t12","t34"]
tsne_out_dir = "../../out/201102/normalized/tsne/"
pca_out_dir = "../../out/201102/normalized/pca/"
data_names = ["pfamA_random","motor_toolkit","pfamA_balanced","pfamA_target","kinesin_labelled"]

# %%
def joint_embed_tsne(target,background):
    jointed = np.concatenate((target, background), axis=0)
    pca_jointed = PCA(n_components=5).fit_transform(jointed)
    jointed_em_2 = TSNE(n_components=2).fit_transform(pca_jointed)
    target_em = jointed_em_2[0:target.shape[0],:]
    background_em = jointed_em_2[target.shape[0]:,:]
    return target_em,background_em

def joint_embed_pca(target,background):
    jointed = np.concatenate((target, background), axis=0)
    pca_jointed = PCA(n_components=2).fit_transform(jointed)
    target_em = pca_jointed[0:target.shape[0],:]
    background_em = pca_jointed[target.shape[0]:,:]
    return target_em,background_em

# %%
# make one directory for each tuning method
import os, sys
for tuning_dir_ in tuning_dir:
    pca_path = pca_out_dir+tuning_dir_
    print(pca_path)
    os.mkdir(pca_path)
    tsne_path = tsne_out_dir+tuning_dir_
    os.mkdir(tsne_path)
# Out:
# ../../out/201102/normalized/pca/t12_balanced
# ../../out/201102/normalized/pca/t12_kinesin
# ../../out/201102/normalized/pca/t12_motor_toolkit
# ../../out/201102/normalized/pca/t12
# ../../out/201102/normalized/pca/t34

# %%
import glob
# for model in models_dir:
import time 

for tuning_dir_ in tuning_dir:
    
#     tuning_dir_ = tuning_dir[4]
    print(tuning_dir_)
    dats = []
    for dat in data_names:
        d_path = hn_dir+'/'+tuning_dir_ +'/'+dat+ '.npy'
#         print(d_path)
        d = np.load(d_path)
        dats.append(d)
    print(dats[0].shape)
    print(dats[1].shape)
    print(dats[2].shape)
    print(dats[3].shape)
    
    # first, embed each of the dataset themselves
    pca_res = []
    tsne_res = []
    for i, dat in enumerate(dats):
        print(data_names[i])
        start_time = time.time()
        pca_curr = PCA(n_components=2).fit_transform(dat)
        pca_res.append(pca_curr)
        tsne_curr = PCA(n_components=10).fit_transform(dat)
        tsne_curr = TSNE(n_components=2).fit_transform(tsne_curr)
        tsne_res.append(tsne_curr)
        print("--- %s seconds ---" % (time.time() - start_time))
  
        
    for i,dat_name in enumerate(data_names):
        pca_out_path = pca_out_dir + tuning_dir_+"/"+dat_name+".npy"
        tsne_out_path = tsne_out_dir + tuning_dir_+"/"+dat_name+".npy"
        print(pca_out_path)
        print(tsne_out_path)
        np.save(pca_out_path, pca_res[i])
        np.save(tsne_out_path, tsne_res[i])
    
    # then, perform several jointly embedding
    #1. target,random
    #2. balanced, random
    for i,j in [(2,0),(3,0)]:
        start_time = time.time()
        target_tsne,background_tsne = joint_embed_tsne(dats[i],dats[j])
        target_pca,background_pca = joint_embed_pca(dats[i],dats[j])
        print("--- %s seconds ---" % (time.time() - start_time))
        pca_out_path_t = pca_out_dir+tuning_dir_+"/"+data_names[i]+"_"+data_names[j]+"_target.npy"
        tsne_out_path_t = tsne_out_dir+tuning_dir_+"/"+data_names[i]+"_"+data_names[j]+"_target.npy"
        pca_out_path_b = pca_out_dir+tuning_dir_+"/"+data_names[i]+"_"+data_names[j]+"_background.npy"
        tsne_out_path_b = tsne_out_dir+tuning_dir_+"/"+data_names[i]+"_"+data_names[j]+"_background.npy"
        print(pca_out_path_t)
        print(pca_out_path_b)
        print(tsne_out_path_t)
        print(tsne_out_path_b)
        np.save(pca_out_path_t, target_pca)
        np.save(pca_out_path_b, background_pca)
        np.save(tsne_out_path_t, target_tsne)
        np.save(tsne_out_path_b, background_tsne)
#     break
# Out:
# t12_balanced
# (1600, 768)
# (3255, 768)
# (18000, 768)
# (5544, 768)
# pfamA_random
# --- 28.558871746063232 seconds ---
# motor_toolkit
# --- 66.02222776412964 seconds ---
# pfamA_balanced
# --- 395.006564617157 seconds ---
# pfamA_target
# --- 110.27404570579529 seconds ---
# kinesin_labelled
# --- 20.00857901573181 seconds ---
# ../../out/201102/normalized/pca/t12_balanced/pfamA_random.npy
# ../../out/201102/normalized/tsne/t12_balanced/pfamA_random.npy
# ../../out/201102/normalized/pca/t12_balanced/motor_toolkit.npy
# ../../out/201102/normalized/tsne/t12_balanced/motor_toolkit.npy
# ../../out/201102/normalized/pca/t12_balanced/pfamA_balanced.npy
# ../../out/201102/normalized/tsne/t12_balanced/pfamA_balanced.npy
# ../../out/201102/normalized/pca/t12_balanced/pfamA_target.npy
# ../../out/201102/normalized/tsne/t12_balanced/pfamA_target.npy
# ../../out/201102/normalized/pca/t12_balanced/kinesin_labelled.npy
# ../../out/201102/normalized/tsne/t12_balanced/kinesin_labelled.npy
# --- 442.8171474933624 seconds ---
# ../../out/201102/normalized/pca/t12_balanced/pfamA_balanced_pfamA_random_target.npy
# ../../out/201102/normalized/pca/t12_balanced/pfamA_balanced_pfamA_random_background.npy
# ../../out/201102/normalized/tsne/t12_balanced/pfamA_balanced_pfamA_random_target.npy
# ../../out/201102/normalized/tsne/t12_balanced/pfamA_balanced_pfamA_random_background.npy
# --- 150.6360466480255 seconds ---
# ../../out/201102/normalized/pca/t12_balanced/pfamA_target_pfamA_random_target.npy
# ../../out/201102/normalized/pca/t12_balanced/pfamA_target_pfamA_random_background.npy
# ../../out/201102/normalized/tsne/t12_balanced/pfamA_target_pfamA_random_target.npy
# ../../out/201102/normalized/tsne/t12_balanced/pfamA_target_pfamA_random_background.npy
# t12_kinesin
# (1600, 768)
# (3255, 768)
# (18000, 768)
# (5544, 768)
# pfamA_random
# --- 29.01128602027893 seconds ---
# motor_toolkit
# --- 65.5870943069458 seconds ---
# pfamA_balanced
# --- 418.06797766685486 seconds ---
# pfamA_target
# --- 112.14603471755981 seconds ---
# kinesin_labelled
# --- 19.645554304122925 seconds ---
# ../../out/201102/normalized/pca/t12_kinesin/pfamA_random.npy
# ../../out/201102/normalized/tsne/t12_kinesin/pfamA_random.npy
# ../../out/201102/normalized/pca/t12_kinesin/motor_toolkit.npy
# ../../out/201102/normalized/tsne/t12_kinesin/motor_toolkit.npy
# ../../out/201102/normalized/pca/t12_kinesin/pfamA_balanced.npy
# ../../out/201102/normalized/tsne/t12_kinesin/pfamA_balanced.npy
# ../../out/201102/normalized/pca/t12_kinesin/pfamA_target.npy
# ../../out/201102/normalized/tsne/t12_kinesin/pfamA_target.npy
# ../../out/201102/normalized/pca/t12_kinesin/kinesin_labelled.npy
# ../../out/201102/normalized/tsne/t12_kinesin/kinesin_labelled.npy
# --- 443.76909136772156 seconds ---
# ../../out/201102/normalized/pca/t12_kinesin/pfamA_balanced_pfamA_random_target.npy
# ../../out/201102/normalized/pca/t12_kinesin/pfamA_balanced_pfamA_random_background.npy
# ../../out/201102/normalized/tsne/t12_kinesin/pfamA_balanced_pfamA_random_target.npy
# ../../out/201102/normalized/tsne/t12_kinesin/pfamA_balanced_pfamA_random_background.npy
# --- 148.7385070323944 seconds ---
# ../../out/201102/normalized/pca/t12_kinesin/pfamA_target_pfamA_random_target.npy
# ../../out/201102/normalized/pca/t12_kinesin/pfamA_target_pfamA_random_background.npy
# ../../out/201102/normalized/tsne/t12_kinesin/pfamA_target_pfamA_random_target.npy
# ../../out/201102/normalized/tsne/t12_kinesin/pfamA_target_pfamA_random_background.npy
# t12_motor_toolkit
# (1600, 768)
# (3255, 768)
# (18000, 768)
# (5544, 768)
# pfamA_random
# --- 28.771661281585693 seconds ---
# motor_toolkit
# --- 63.77827286720276 seconds ---
# pfamA_balanced
# --- 459.0866312980652 seconds ---
# pfamA_target
# --- 130.3233094215393 seconds ---
# kinesin_labelled
# --- 22.667381048202515 seconds ---
# ../../out/201102/normalized/pca/t12_motor_toolkit/pfamA_random.npy
# ../../out/201102/normalized/tsne/t12_motor_toolkit/pfamA_random.npy
# ../../out/201102/normalized/pca/t12_motor_toolkit/motor_toolkit.npy
# ../../out/201102/normalized/tsne/t12_motor_toolkit/motor_toolkit.npy
# ../../out/201102/normalized/pca/t12_motor_toolkit/pfamA_balanced.npy
# ../../out/201102/normalized/tsne/t12_motor_toolkit/pfamA_balanced.npy
# ../../out/201102/normalized/pca/t12_motor_toolkit/pfamA_target.npy
# ../../out/201102/normalized/tsne/t12_motor_toolkit/pfamA_target.npy
# ../../out/201102/normalized/pca/t12_motor_toolkit/kinesin_labelled.npy
# ../../out/201102/normalized/tsne/t12_motor_toolkit/kinesin_labelled.npy
# --- 440.1469397544861 seconds ---
# ../../out/201102/normalized/pca/t12_motor_toolkit/pfamA_balanced_pfamA_random_target.npy
# ../../out/201102/normalized/pca/t12_motor_toolkit/pfamA_balanced_pfamA_random_background.npy
# ../../out/201102/normalized/tsne/t12_motor_toolkit/pfamA_balanced_pfamA_random_target.npy
# ../../out/201102/normalized/tsne/t12_motor_toolkit/pfamA_balanced_pfamA_random_background.npy
# --- 152.32113552093506 seconds ---
# ../../out/201102/normalized/pca/t12_motor_toolkit/pfamA_target_pfamA_random_target.npy
# ../../out/201102/normalized/pca/t12_motor_toolkit/pfamA_target_pfamA_random_background.npy
# ../../out/201102/normalized/tsne/t12_motor_toolkit/pfamA_target_pfamA_random_target.npy
# ../../out/201102/normalized/tsne/t12_motor_toolkit/pfamA_target_pfamA_random_background.npy
# t12
# (1600, 768)
# (3255, 768)
# (18000, 768)
# (5544, 768)
# pfamA_random
# --- 27.361266136169434 seconds ---
# motor_toolkit
# --- 69.19127368927002 seconds ---
# pfamA_balanced
# --- 443.08267736434937 seconds ---
# pfamA_target
# --- 118.29868960380554 seconds ---
# kinesin_labelled
# --- 19.50808310508728 seconds ---
# ../../out/201102/normalized/pca/t12/pfamA_random.npy
# ../../out/201102/normalized/tsne/t12/pfamA_random.npy
# ../../out/201102/normalized/pca/t12/motor_toolkit.npy
# ../../out/201102/normalized/tsne/t12/motor_toolkit.npy
# ../../out/201102/normalized/pca/t12/pfamA_balanced.npy
# ../../out/201102/normalized/tsne/t12/pfamA_balanced.npy
# ../../out/201102/normalized/pca/t12/pfamA_target.npy
# ../../out/201102/normalized/tsne/t12/pfamA_target.npy
# ../../out/201102/normalized/pca/t12/kinesin_labelled.npy
# ../../out/201102/normalized/tsne/t12/kinesin_labelled.npy
# --- 420.5239074230194 seconds ---
# ../../out/201102/normalized/pca/t12/pfamA_balanced_pfamA_random_target.npy
# ../../out/201102/normalized/pca/t12/pfamA_balanced_pfamA_random_background.npy
# ../../out/201102/normalized/tsne/t12/pfamA_balanced_pfamA_random_target.npy
# ../../out/201102/normalized/tsne/t12/pfamA_balanced_pfamA_random_background.npy
# --- 138.93813729286194 seconds ---
# ../../out/201102/normalized/pca/t12/pfamA_target_pfamA_random_target.npy
# ../../out/201102/normalized/pca/t12/pfamA_target_pfamA_random_background.npy
# ../../out/201102/normalized/tsne/t12/pfamA_target_pfamA_random_target.npy
# ../../out/201102/normalized/tsne/t12/pfamA_target_pfamA_random_background.npy
# t34
# (1600, 1280)
# (3255, 1280)
# (18000, 1280)
# (5544, 1280)
# pfamA_random
# --- 28.602500915527344 seconds ---
# motor_toolkit
# --- 62.0221209526062 seconds ---
# pfamA_balanced
# --- 380.6761770248413 seconds ---
# pfamA_target
# --- 106.44688129425049 seconds ---
# kinesin_labelled
# --- 19.132872819900513 seconds ---
# ../../out/201102/normalized/pca/t34/pfamA_random.npy
# ../../out/201102/normalized/tsne/t34/pfamA_random.npy
# ../../out/201102/normalized/pca/t34/motor_toolkit.npy
# ../../out/201102/normalized/tsne/t34/motor_toolkit.npy
# ../../out/201102/normalized/pca/t34/pfamA_balanced.npy
# ../../out/201102/normalized/tsne/t34/pfamA_balanced.npy
# ../../out/201102/normalized/pca/t34/pfamA_target.npy
# ../../out/201102/normalized/tsne/t34/pfamA_target.npy
# ../../out/201102/normalized/pca/t34/kinesin_labelled.npy
# ../../out/201102/normalized/tsne/t34/kinesin_labelled.npy
# --- 416.6196668148041 seconds ---
# ../../out/201102/normalized/pca/t34/pfamA_balanced_pfamA_random_target.npy
# ../../out/201102/normalized/pca/t34/pfamA_balanced_pfamA_random_background.npy
# ../../out/201102/normalized/tsne/t34/pfamA_balanced_pfamA_random_target.npy
# ../../out/201102/normalized/tsne/t34/pfamA_balanced_pfamA_random_background.npy
# --- 138.94690489768982 seconds ---
# ../../out/201102/normalized/pca/t34/pfamA_target_pfamA_random_target.npy
# ../../out/201102/normalized/pca/t34/pfamA_target_pfamA_random_background.npy
# ../../out/201102/normalized/tsne/t34/pfamA_target_pfamA_random_target.npy
# ../../out/201102/normalized/tsne/t34/pfamA_target_pfamA_random_background.npy
